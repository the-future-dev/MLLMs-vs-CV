# %%
import clip
import json
import numpy as np
import torch
from torchvision import datasets
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
model, preprocess = clip.load("ViT-B/32", device="cpu")

# %%
dataset = datasets.ImageFolder(
    root='dataset/mini-ImageNet',
    transform=preprocess,
)

with open('dataset/mini-ImageNet/imagenet_class_index.json') as f:
    class_index = json.load(f)

folder_to_class = {value[0]: value[1] for key, value in class_index.items()}
all_classes = [folder_to_class[folder] for folder in dataset.classes]
all_classes
# Out:
# ['house_finch',
#  'robin',
#  'triceratops',
#  'green_mamba',
#  'harvestman',
#  'toucan',
#  'goose',
#  'jellyfish',
#  'nematode',
#  'king_crab',
#  'dugong',
#  'Walker_hound',
#  'Ibizan_hound',
#  'Saluki',
#  'golden_retriever',
#  'Gordon_setter',
#  'komondor',
#  'boxer',
#  'Tibetan_mastiff',
#  'French_bulldog',
#  'malamute',
#  'dalmatian',
#  'Newfoundland',
#  'miniature_poodle',
#  'white_wolf',
#  'African_hunting_dog',
#  'Arctic_fox',
#  'lion',
#  'meerkat',
#  'ladybug',
#  'rhinoceros_beetle',
#  'ant',
#  'black-footed_ferret',
#  'three-toed_sloth',
#  'rock_beauty',
#  'aircraft_carrier',
#  'ashcan',
#  'barrel',
#  'beer_bottle',
#  'bookshop',
#  'cannon',
#  'carousel',
#  'carton',
#  'catamaran',
#  'chime',
#  'clog',
#  'cocktail_shaker',
#  'combination_lock',
#  'crate',
#  'cuirass',
#  'dishrag',
#  'dome',
#  'electric_guitar',
#  'file',
#  'fire_screen',
#  'frying_pan',
#  'garbage_truck',
#  'hair_slide',
#  'holster',
#  'horizontal_bar',
#  'hourglass',
#  'iPod',
#  'lipstick',
#  'miniskirt',
#  'missile',
#  'mixing_bowl',
#  'oboe',
#  'organ',
#  'parallel_bars',
#  'pencil_box',
#  'photocopier',
#  'poncho',
#  'prayer_rug',
#  'reel',
#  'school_bus',
#  'scoreboard',
#  'slot',
#  'snorkel',
#  'solar_dish',
#  'spider_web',
#  'stage',
#  'tank',
#  'theater_curtain',
#  'tile_roof',
#  'tobacco_shop',
#  'unicycle',
#  'upright',
#  'vase',
#  'wok',
#  'worm_fence',
#  'yawl',
#  'street_sign',
#  'consomme',
#  'trifle',
#  'hotdog',
#  'orange',
#  'cliff',
#  'coral_reef',
#  'bolete',
#  'ear']

# %%
adjusted_labels = []
for label in all_classes:
    adjusted_labels.append(f'the image of a {label}')

token_text = clip.tokenize(adjusted_labels).to("cpu")

# %%
true_labels = []
pred_labels = []
checkpoint_interval = 100

with torch.no_grad():
    text_features = model.encode_text(token_text)

    for i in range(0, 10000):
        image, label = dataset[i]
        image = image.unsqueeze(0)
        image = image.to("cpu")
        
        with torch.no_grad():
            image_features = model.encode_image(image)

        similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)
        prediction = int(similarity.argmax(dim=-1).cpu().numpy()[0])

        # print(f"Label: {label} \nPrediction: {prediction}")
        true_labels.append(label)
        pred_labels.append(prediction)

        print(f'{i} | True: {all_classes[label]} | Predicted: {all_classes[prediction]}')

        if i % checkpoint_interval == 0:
            # Save the true and predicted labels
            np.save(f'results/true_labels.npy', true_labels)
            np.save(f'results/pred_labels.npy', pred_labels)
# Out:
# 0 | True: house_finch | Predicted: house_finch
# 1 | True: house_finch | Predicted: house_finch
# 2 | True: house_finch | Predicted: house_finch
# 3 | True: house_finch | Predicted: house_finch
# 4 | True: house_finch | Predicted: house_finch
# 5 | True: house_finch | Predicted: house_finch
# 6 | True: house_finch | Predicted: house_finch
# 7 | True: house_finch | Predicted: house_finch
# 8 | True: house_finch | Predicted: house_finch
# 9 | True: house_finch | Predicted: yawl
# 10 | True: house_finch | Predicted: house_finch
# 11 | True: house_finch | Predicted: house_finch
# 12 | True: house_finch | Predicted: yawl
# 13 | True: house_finch | Predicted: house_finch
# 14 | True: house_finch | Predicted: house_finch
# 15 | True: house_finch | Predicted: house_finch
# 16 | True: house_finch | Predicted: house_finch
# 17 | True: house_finch | Predicted: house_finch
# 18 | True: house_finch | Predicted: house_finch
# 19 | True: house_finch | Predicted: house_finch
# 20 | True: house_finch | Predicted: house_finch
# 21 | True: house_finch | Predicted: house_finch
# 22 | True: house_finch | Predicted: house_finch
# 23 | True: house_finch | Predicted: house_finch
# 24 | True: house_finch | Predicted: house_finch
# 25 | True: house_finch | Predicted: house_finch
# 26 | True: house_finch | Predicted: house_finch
# 27 | True: house_finch | Predicted: house_finch
# 28 | True: house_finch | Predicted: house_finch
# 29 | True: house_finch | Predicted: house_finch
# 30 | True: house_finch | Predicted: house_finch
# 31 | True: house_finch | Predicted: house_finch
# 32 | True: house_finch | Predicted: house_finch
# 33 | True: house_finch | Predicted: house_finch
# 34 | True: house_finch | Predicted: house_finch
# 35 | True: house_finch | Predicted: robin
# 36 | True: house_finch | Predicted: house_finch
# 37 | True: house_finch | Predicted: house_finch
# 38 | True: house_finch | Predicted: yawl
# 39 | True: house_finch | Predicted: house_finch
# 40 | True: house_finch | Predicted: house_finch
# 41 | True: house_finch | Predicted: house_finch
# 42 | True: house_finch | Predicted: yawl
# 43 | True: house_finch | Predicted: house_finch
# 44 | True: house_finch | Predicted: house_finch
# 45 | True: house_finch | Predicted: house_finch
# 46 | True: house_finch | Predicted: house_finch
# 47 | True: house_finch | Predicted: house_finch
# 48 | True: house_finch | Predicted: house_finch
# 49 | True: house_finch | Predicted: house_finch
# 50 | True: house_finch | Predicted: house_finch
# 51 | True: house_finch | Predicted: yawl
# 52 | True: house_finch | Predicted: house_finch
# 53 | True: house_finch | Predicted: house_finch
# 54 | True: house_finch | Predicted: house_finch
# 55 | True: house_finch | Predicted: house_finch
# 56 | True: house_finch | Predicted: house_finch
# 57 | True: house_finch | Predicted: house_finch
# 58 | True: house_finch | Predicted: house_finch
# 59 | True: house_finch | Predicted: house_finch
# 60 | True: house_finch | Predicted: house_finch
# 61 | True: house_finch | Predicted: house_finch
# 62 | True: house_finch | Predicted: house_finch
# 63 | True: house_finch | Predicted: yawl
# 64 | True: house_finch | Predicted: robin
# 65 | True: house_finch | Predicted: house_finch
# 66 | True: house_finch | Predicted: house_finch
# 67 | True: house_finch | Predicted: house_finch
# 68 | True: house_finch | Predicted: house_finch
# 69 | True: house_finch | Predicted: house_finch
# 70 | True: house_finch | Predicted: house_finch
# 71 | True: house_finch | Predicted: house_finch
# 72 | True: house_finch | Predicted: house_finch
# 73 | True: house_finch | Predicted: house_finch
# 74 | True: house_finch | Predicted: house_finch
# 75 | True: house_finch | Predicted: house_finch
# 76 | True: house_finch | Predicted: house_finch
# 77 | True: house_finch | Predicted: house_finch
# 78 | True: house_finch | Predicted: house_finch
# 79 | True: house_finch | Predicted: house_finch
# 80 | True: house_finch | Predicted: chime
# 81 | True: house_finch | Predicted: house_finch
# 82 | True: house_finch | Predicted: house_finch
# 83 | True: house_finch | Predicted: house_finch
# 84 | True: house_finch | Predicted: robin
# 85 | True: house_finch | Predicted: yawl
# 86 | True: house_finch | Predicted: house_finch
# 87 | True: house_finch | Predicted: house_finch
# 88 | True: house_finch | Predicted: house_finch
# 89 | True: house_finch | Predicted: yawl
# 90 | True: house_finch | Predicted: house_finch
# 91 | True: house_finch | Predicted: house_finch
# 92 | True: house_finch | Predicted: house_finch
# 93 | True: house_finch | Predicted: house_finch
# 94 | True: house_finch | Predicted: yawl
# 95 | True: house_finch | Predicted: yawl
# 96 | True: house_finch | Predicted: house_finch
# 97 | True: house_finch | Predicted: house_finch
# 98 | True: house_finch | Predicted: house_finch
# 99 | True: house_finch | Predicted: house_finch
# 100 | True: robin | Predicted: robin
# 101 | True: robin | Predicted: robin
# 102 | True: robin | Predicted: robin
# 103 | True: robin | Predicted: robin
# 104 | True: robin | Predicted: yawl
# 105 | True: robin | Predicted: robin
# 106 | True: robin | Predicted: robin
# 107 | True: robin | Predicted: yawl
# 108 | True: robin | Predicted: robin
# 109 | True: robin | Predicted: robin
# 110 | True: robin | Predicted: robin
# 111 | True: robin | Predicted: robin
# 112 | True: robin | Predicted: robin
# 113 | True: robin | Predicted: robin
# 114 | True: robin | Predicted: robin
# 115 | True: robin | Predicted: robin
# 116 | True: robin | Predicted: robin
# 117 | True: robin | Predicted: robin
# 118 | True: robin | Predicted: robin
# 119 | True: robin | Predicted: robin
# 120 | True: robin | Predicted: yawl
# 121 | True: robin | Predicted: robin
# 122 | True: robin | Predicted: robin
# 123 | True: robin | Predicted: robin
# 124 | True: robin | Predicted: robin
# 125 | True: robin | Predicted: robin
# 126 | True: robin | Predicted: robin
# 127 | True: robin | Predicted: robin
# 128 | True: robin | Predicted: robin
# 129 | True: robin | Predicted: robin
# 130 | True: robin | Predicted: robin
# 131 | True: robin | Predicted: robin
# 132 | True: robin | Predicted: robin
# 133 | True: robin | Predicted: robin
# 134 | True: robin | Predicted: yawl
# 135 | True: robin | Predicted: robin
# 136 | True: robin | Predicted: robin
# 137 | True: robin | Predicted: yawl
# 138 | True: robin | Predicted: robin
# 139 | True: robin | Predicted: robin
# 140 | True: robin | Predicted: robin
# 141 | True: robin | Predicted: robin
# 142 | True: robin | Predicted: yawl
# 143 | True: robin | Predicted: robin
# 144 | True: robin | Predicted: robin
# 145 | True: robin | Predicted: yawl
# 146 | True: robin | Predicted: robin
# 147 | True: robin | Predicted: robin
# 148 | True: robin | Predicted: robin
# 149 | True: robin | Predicted: robin
# 150 | True: robin | Predicted: robin
# 151 | True: robin | Predicted: yawl
# 152 | True: robin | Predicted: robin
# 153 | True: robin | Predicted: robin
# 154 | True: robin | Predicted: robin
# 155 | True: robin | Predicted: yawl
# 156 | True: robin | Predicted: yawl
# 157 | True: robin | Predicted: robin
# 158 | True: robin | Predicted: robin
# 159 | True: robin | Predicted: robin
# 160 | True: robin | Predicted: robin
# 161 | True: robin | Predicted: robin
# 162 | True: robin | Predicted: robin
# 163 | True: robin | Predicted: robin
# 164 | True: robin | Predicted: yawl
# 165 | True: robin | Predicted: robin
# 166 | True: robin | Predicted: yawl
# 167 | True: robin | Predicted: robin
# 168 | True: robin | Predicted: robin
# 169 | True: robin | Predicted: yawl
# 170 | True: robin | Predicted: robin
# 171 | True: robin | Predicted: robin
# 172 | True: robin | Predicted: robin
# 173 | True: robin | Predicted: yawl
# 174 | True: robin | Predicted: robin
# 175 | True: robin | Predicted: robin
# 176 | True: robin | Predicted: robin
# 177 | True: robin | Predicted: robin
# 178 | True: robin | Predicted: robin
# 179 | True: robin | Predicted: robin
# 180 | True: robin | Predicted: robin
# 181 | True: robin | Predicted: robin
# 182 | True: robin | Predicted: robin
# 183 | True: robin | Predicted: yawl
# 184 | True: robin | Predicted: robin
# 185 | True: robin | Predicted: yawl
# 186 | True: robin | Predicted: robin
# 187 | True: robin | Predicted: robin
# 188 | True: robin | Predicted: yawl
# 189 | True: robin | Predicted: robin
# 190 | True: robin | Predicted: robin
# 191 | True: robin | Predicted: robin
# 192 | True: robin | Predicted: robin
# 193 | True: robin | Predicted: robin
# 194 | True: robin | Predicted: robin
# 195 | True: robin | Predicted: robin
# 196 | True: robin | Predicted: robin
# 197 | True: robin | Predicted: robin
# 198 | True: robin | Predicted: robin
# 199 | True: robin | Predicted: robin
# 200 | True: triceratops | Predicted: yawl
# 201 | True: triceratops | Predicted: triceratops
# 202 | True: triceratops | Predicted: yawl
# 203 | True: triceratops | Predicted: yawl
# 204 | True: triceratops | Predicted: triceratops
# 205 | True: triceratops | Predicted: triceratops
# 206 | True: triceratops | Predicted: African_hunting_dog
# 207 | True: triceratops | Predicted: triceratops
# 208 | True: triceratops | Predicted: triceratops
# 209 | True: triceratops | Predicted: yawl
# 210 | True: triceratops | Predicted: yawl
# 211 | True: triceratops | Predicted: yawl
# 212 | True: triceratops | Predicted: yawl
# 213 | True: triceratops | Predicted: triceratops
# 214 | True: triceratops | Predicted: white_wolf
# 215 | True: triceratops | Predicted: yawl
# 216 | True: triceratops | Predicted: yawl
# 217 | True: triceratops | Predicted: triceratops
# 218 | True: triceratops | Predicted: yawl
# 219 | True: triceratops | Predicted: yawl
# 220 | True: triceratops | Predicted: stage
# 221 | True: triceratops | Predicted: triceratops
# 222 | True: triceratops | Predicted: triceratops
# 223 | True: triceratops | Predicted: yawl
# 224 | True: triceratops | Predicted: yawl
# 225 | True: triceratops | Predicted: triceratops
# 226 | True: triceratops | Predicted: yawl
# 227 | True: triceratops | Predicted: yawl
# 228 | True: triceratops | Predicted: yawl
# 229 | True: triceratops | Predicted: yawl
# 230 | True: triceratops | Predicted: yawl
# 231 | True: triceratops | Predicted: triceratops
# 232 | True: triceratops | Predicted: yawl
# 233 | True: triceratops | Predicted: fire_screen
# 234 | True: triceratops | Predicted: yawl
# 235 | True: triceratops | Predicted: file
# 236 | True: triceratops | Predicted: yawl
# 237 | True: triceratops | Predicted: yawl
# 238 | True: triceratops | Predicted: yawl
# 239 | True: triceratops | Predicted: yawl
# 240 | True: triceratops | Predicted: yawl
# 241 | True: triceratops | Predicted: triceratops
# 242 | True: triceratops | Predicted: yawl
# 243 | True: triceratops | Predicted: yawl
# 244 | True: triceratops | Predicted: triceratops
# 245 | True: triceratops | Predicted: yawl
# 246 | True: triceratops | Predicted: triceratops
# 247 | True: triceratops | Predicted: yawl
# 248 | True: triceratops | Predicted: triceratops
# 249 | True: triceratops | Predicted: triceratops
# 250 | True: triceratops | Predicted: yawl
# 251 | True: triceratops | Predicted: yawl
# 252 | True: triceratops | Predicted: yawl
# 253 | True: triceratops | Predicted: triceratops
# 254 | True: triceratops | Predicted: yawl
# 255 | True: triceratops | Predicted: yawl
# 256 | True: triceratops | Predicted: yawl
# 257 | True: triceratops | Predicted: yawl
# 258 | True: triceratops | Predicted: yawl
# 259 | True: triceratops | Predicted: yawl
# 260 | True: triceratops | Predicted: yawl
# 261 | True: triceratops | Predicted: yawl
# 262 | True: triceratops | Predicted: triceratops
# 263 | True: triceratops | Predicted: triceratops
# 264 | True: triceratops | Predicted: triceratops
# 265 | True: triceratops | Predicted: yawl
# 266 | True: triceratops | Predicted: yawl
# 267 | True: triceratops | Predicted: ashcan
# 268 | True: triceratops | Predicted: fire_screen
# 269 | True: triceratops | Predicted: triceratops
# 270 | True: triceratops | Predicted: triceratops
# 271 | True: triceratops | Predicted: yawl
# 272 | True: triceratops | Predicted: triceratops
# 273 | True: triceratops | Predicted: yawl
# 274 | True: triceratops | Predicted: triceratops
# 275 | True: triceratops | Predicted: triceratops
# 276 | True: triceratops | Predicted: white_wolf
# 277 | True: triceratops | Predicted: yawl
# 278 | True: triceratops | Predicted: triceratops
# 279 | True: triceratops | Predicted: triceratops
# 280 | True: triceratops | Predicted: ashcan
# 281 | True: triceratops | Predicted: yawl
# 282 | True: triceratops | Predicted: yawl
# 283 | True: triceratops | Predicted: ashcan
# 284 | True: triceratops | Predicted: yawl
# 285 | True: triceratops | Predicted: triceratops
# 286 | True: triceratops | Predicted: triceratops
# 287 | True: triceratops | Predicted: yawl
# 288 | True: triceratops | Predicted: yawl
# 289 | True: triceratops | Predicted: triceratops
# 290 | True: triceratops | Predicted: yawl
# 291 | True: triceratops | Predicted: yawl
# 292 | True: triceratops | Predicted: triceratops
# 293 | True: triceratops | Predicted: yawl
# 294 | True: triceratops | Predicted: triceratops
# 295 | True: triceratops | Predicted: yawl
# 296 | True: triceratops | Predicted: yawl
# 297 | True: triceratops | Predicted: yawl
# 298 | True: triceratops | Predicted: yawl
# 299 | True: triceratops | Predicted: yawl
# 300 | True: green_mamba | Predicted: yawl
# 301 | True: green_mamba | Predicted: yawl
# 302 | True: green_mamba | Predicted: yawl
# 303 | True: green_mamba | Predicted: yawl
# 304 | True: green_mamba | Predicted: green_mamba
# 305 | True: green_mamba | Predicted: yawl
# 306 | True: green_mamba | Predicted: green_mamba
# 307 | True: green_mamba | Predicted: green_mamba
# 308 | True: green_mamba | Predicted: green_mamba
# 309 | True: green_mamba | Predicted: yawl
# 310 | True: green_mamba | Predicted: yawl
# 311 | True: green_mamba | Predicted: green_mamba
# 312 | True: green_mamba | Predicted: yawl
# 313 | True: green_mamba | Predicted: yawl
# 314 | True: green_mamba | Predicted: yawl
# 315 | True: green_mamba | Predicted: green_mamba
# 316 | True: green_mamba | Predicted: yawl
# 317 | True: green_mamba | Predicted: yawl
# 318 | True: green_mamba | Predicted: green_mamba
# 319 | True: green_mamba | Predicted: yawl
# 320 | True: green_mamba | Predicted: yawl
# 321 | True: green_mamba | Predicted: yawl
# 322 | True: green_mamba | Predicted: yawl
# 323 | True: green_mamba | Predicted: green_mamba
# 324 | True: green_mamba | Predicted: green_mamba
# 325 | True: green_mamba | Predicted: green_mamba
# 326 | True: green_mamba | Predicted: yawl
# 327 | True: green_mamba | Predicted: yawl
# 328 | True: green_mamba | Predicted: green_mamba
# 329 | True: green_mamba | Predicted: yawl
# 330 | True: green_mamba | Predicted: yawl
# 331 | True: green_mamba | Predicted: yawl
# 332 | True: green_mamba | Predicted: yawl
# 333 | True: green_mamba | Predicted: green_mamba
# 334 | True: green_mamba | Predicted: ashcan
# 335 | True: green_mamba | Predicted: green_mamba
# 336 | True: green_mamba | Predicted: yawl
# 337 | True: green_mamba | Predicted: yawl
# 338 | True: green_mamba | Predicted: green_mamba
# 339 | True: green_mamba | Predicted: yawl
# 340 | True: green_mamba | Predicted: green_mamba
# 341 | True: green_mamba | Predicted: green_mamba
# 342 | True: green_mamba | Predicted: green_mamba
# 343 | True: green_mamba | Predicted: yawl
# 344 | True: green_mamba | Predicted: yawl
# 345 | True: green_mamba | Predicted: yawl
# 346 | True: green_mamba | Predicted: green_mamba
# 347 | True: green_mamba | Predicted: yawl
# 348 | True: green_mamba | Predicted: green_mamba
# 349 | True: green_mamba | Predicted: green_mamba
# 350 | True: green_mamba | Predicted: yawl
# 351 | True: green_mamba | Predicted: green_mamba
# 352 | True: green_mamba | Predicted: yawl
# 353 | True: green_mamba | Predicted: green_mamba
# 354 | True: green_mamba | Predicted: green_mamba
# 355 | True: green_mamba | Predicted: yawl
# 356 | True: green_mamba | Predicted: green_mamba
# 357 | True: green_mamba | Predicted: yawl
# 358 | True: green_mamba | Predicted: yawl
# 359 | True: green_mamba | Predicted: green_mamba
# 360 | True: green_mamba | Predicted: yawl
# 361 | True: green_mamba | Predicted: green_mamba
# 362 | True: green_mamba | Predicted: green_mamba
# 363 | True: green_mamba | Predicted: yawl
# 364 | True: green_mamba | Predicted: yawl
# 365 | True: green_mamba | Predicted: green_mamba
# 366 | True: green_mamba | Predicted: yawl
# 367 | True: green_mamba | Predicted: yawl
# 368 | True: green_mamba | Predicted: yawl
# 369 | True: green_mamba | Predicted: yawl
# 370 | True: green_mamba | Predicted: yawl
# 371 | True: green_mamba | Predicted: yawl
# 372 | True: green_mamba | Predicted: yawl
# 373 | True: green_mamba | Predicted: yawl
# 374 | True: green_mamba | Predicted: yawl
# 375 | True: green_mamba | Predicted: green_mamba
# 376 | True: green_mamba | Predicted: yawl
# 377 | True: green_mamba | Predicted: yawl
# 378 | True: green_mamba | Predicted: green_mamba
# 379 | True: green_mamba | Predicted: green_mamba
# 380 | True: green_mamba | Predicted: green_mamba
# 381 | True: green_mamba | Predicted: yawl
# 382 | True: green_mamba | Predicted: yawl
# 383 | True: green_mamba | Predicted: yawl
# 384 | True: green_mamba | Predicted: green_mamba
# 385 | True: green_mamba | Predicted: yawl
# 386 | True: green_mamba | Predicted: yawl
# 387 | True: green_mamba | Predicted: green_mamba
# 388 | True: green_mamba | Predicted: green_mamba
# 389 | True: green_mamba | Predicted: yawl
# 390 | True: green_mamba | Predicted: green_mamba
# 391 | True: green_mamba | Predicted: green_mamba
# 392 | True: green_mamba | Predicted: green_mamba
# 393 | True: green_mamba | Predicted: yawl
# 394 | True: green_mamba | Predicted: yawl
# 395 | True: green_mamba | Predicted: yawl
# 396 | True: green_mamba | Predicted: green_mamba
# 397 | True: green_mamba | Predicted: green_mamba
# 398 | True: green_mamba | Predicted: yawl
# 399 | True: green_mamba | Predicted: yawl
# 400 | True: harvestman | Predicted: harvestman
# 401 | True: harvestman | Predicted: spider_web
# 402 | True: harvestman | Predicted: harvestman
# 403 | True: harvestman | Predicted: spider_web
# 404 | True: harvestman | Predicted: yawl
# 405 | True: harvestman | Predicted: harvestman
# 406 | True: harvestman | Predicted: spider_web
# 407 | True: harvestman | Predicted: harvestman
# 408 | True: harvestman | Predicted: spider_web
# 409 | True: harvestman | Predicted: spider_web
# 410 | True: harvestman | Predicted: spider_web
# 411 | True: harvestman | Predicted: spider_web
# 412 | True: harvestman | Predicted: spider_web
# 413 | True: harvestman | Predicted: spider_web
# 414 | True: harvestman | Predicted: yawl
# 415 | True: harvestman | Predicted: spider_web
# 416 | True: harvestman | Predicted: spider_web
# 417 | True: harvestman | Predicted: spider_web
# 418 | True: harvestman | Predicted: harvestman
# 419 | True: harvestman | Predicted: spider_web
# 420 | True: harvestman | Predicted: yawl
# 421 | True: harvestman | Predicted: spider_web
# 422 | True: harvestman | Predicted: spider_web
# 423 | True: harvestman | Predicted: ant
# 424 | True: harvestman | Predicted: spider_web
# 425 | True: harvestman | Predicted: yawl
# 426 | True: harvestman | Predicted: spider_web
# 427 | True: harvestman | Predicted: spider_web
# 428 | True: harvestman | Predicted: spider_web
# 429 | True: harvestman | Predicted: spider_web
# 430 | True: harvestman | Predicted: spider_web
# 431 | True: harvestman | Predicted: spider_web
# 432 | True: harvestman | Predicted: spider_web
# 433 | True: harvestman | Predicted: spider_web
# 434 | True: harvestman | Predicted: spider_web
# 435 | True: harvestman | Predicted: spider_web
# 436 | True: harvestman | Predicted: harvestman
# 437 | True: harvestman | Predicted: harvestman
# 438 | True: harvestman | Predicted: spider_web
# 439 | True: harvestman | Predicted: harvestman
# 440 | True: harvestman | Predicted: yawl
# 441 | True: harvestman | Predicted: ant
# 442 | True: harvestman | Predicted: ant
# 443 | True: harvestman | Predicted: spider_web
# 444 | True: harvestman | Predicted: spider_web
# 445 | True: harvestman | Predicted: spider_web
# 446 | True: harvestman | Predicted: harvestman
# 447 | True: harvestman | Predicted: spider_web
# 448 | True: harvestman | Predicted: spider_web
# 449 | True: harvestman | Predicted: spider_web
# 450 | True: harvestman | Predicted: spider_web
# 451 | True: harvestman | Predicted: spider_web
# 452 | True: harvestman | Predicted: harvestman
# 453 | True: harvestman | Predicted: spider_web
# 454 | True: harvestman | Predicted: harvestman
# 455 | True: harvestman | Predicted: ant
# 456 | True: harvestman | Predicted: spider_web
# 457 | True: harvestman | Predicted: harvestman
# 458 | True: harvestman | Predicted: spider_web
# 459 | True: harvestman | Predicted: spider_web
# 460 | True: harvestman | Predicted: spider_web
# 461 | True: harvestman | Predicted: yawl
# 462 | True: harvestman | Predicted: harvestman
# 463 | True: harvestman | Predicted: spider_web
# 464 | True: harvestman | Predicted: spider_web
# 465 | True: harvestman | Predicted: yawl
# 466 | True: harvestman | Predicted: yawl
# 467 | True: harvestman | Predicted: ant
# 468 | True: harvestman | Predicted: spider_web
# 469 | True: harvestman | Predicted: spider_web
# 470 | True: harvestman | Predicted: yawl
# 471 | True: harvestman | Predicted: spider_web
# 472 | True: harvestman | Predicted: spider_web
# 473 | True: harvestman | Predicted: harvestman
# 474 | True: harvestman | Predicted: spider_web
# 475 | True: harvestman | Predicted: spider_web
# 476 | True: harvestman | Predicted: ant
# 477 | True: harvestman | Predicted: harvestman
# 478 | True: harvestman | Predicted: spider_web
# 479 | True: harvestman | Predicted: spider_web
# 480 | True: harvestman | Predicted: harvestman
# 481 | True: harvestman | Predicted: spider_web
# 482 | True: harvestman | Predicted: spider_web
# 483 | True: harvestman | Predicted: spider_web
# 484 | True: harvestman | Predicted: spider_web
# 485 | True: harvestman | Predicted: spider_web
# 486 | True: harvestman | Predicted: spider_web
# 487 | True: harvestman | Predicted: spider_web
# 488 | True: harvestman | Predicted: spider_web
# 489 | True: harvestman | Predicted: spider_web
# 490 | True: harvestman | Predicted: spider_web
# 491 | True: harvestman | Predicted: spider_web
# 492 | True: harvestman | Predicted: yawl
# 493 | True: harvestman | Predicted: spider_web
# 494 | True: harvestman | Predicted: spider_web
# 495 | True: harvestman | Predicted: spider_web
# 496 | True: harvestman | Predicted: harvestman
# 497 | True: harvestman | Predicted: spider_web
# 498 | True: harvestman | Predicted: spider_web
# 499 | True: harvestman | Predicted: spider_web
# 500 | True: toucan | Predicted: toucan
# 501 | True: toucan | Predicted: toucan
# 502 | True: toucan | Predicted: toucan
# 503 | True: toucan | Predicted: yawl
# 504 | True: toucan | Predicted: yawl
# 505 | True: toucan | Predicted: yawl
# 506 | True: toucan | Predicted: toucan
# 507 | True: toucan | Predicted: yawl
# 508 | True: toucan | Predicted: yawl
# 509 | True: toucan | Predicted: yawl
# 510 | True: toucan | Predicted: yawl
# 511 | True: toucan | Predicted: yawl
# 512 | True: toucan | Predicted: toucan
# 513 | True: toucan | Predicted: yawl
# 514 | True: toucan | Predicted: yawl
# 515 | True: toucan | Predicted: toucan
# 516 | True: toucan | Predicted: toucan
# 517 | True: toucan | Predicted: yawl
# 518 | True: toucan | Predicted: yawl
# 519 | True: toucan | Predicted: yawl
# 520 | True: toucan | Predicted: yawl
# 521 | True: toucan | Predicted: toucan
# 522 | True: toucan | Predicted: yawl
# 523 | True: toucan | Predicted: toucan
# 524 | True: toucan | Predicted: yawl
# 525 | True: toucan | Predicted: yawl
# 526 | True: toucan | Predicted: yawl
# 527 | True: toucan | Predicted: toucan
# 528 | True: toucan | Predicted: yawl
# 529 | True: toucan | Predicted: yawl
# 530 | True: toucan | Predicted: toucan
# 531 | True: toucan | Predicted: yawl
# 532 | True: toucan | Predicted: file
# 533 | True: toucan | Predicted: yawl
# 534 | True: toucan | Predicted: yawl
# 535 | True: toucan | Predicted: yawl
# 536 | True: toucan | Predicted: yawl
# 537 | True: toucan | Predicted: yawl
# 538 | True: toucan | Predicted: yawl
# 539 | True: toucan | Predicted: yawl
# 540 | True: toucan | Predicted: yawl
# 541 | True: toucan | Predicted: yawl
# 542 | True: toucan | Predicted: yawl
# 543 | True: toucan | Predicted: yawl
# 544 | True: toucan | Predicted: toucan
# 545 | True: toucan | Predicted: yawl
# 546 | True: toucan | Predicted: toucan
# 547 | True: toucan | Predicted: yawl
# 548 | True: toucan | Predicted: toucan
# 549 | True: toucan | Predicted: toucan
# 550 | True: toucan | Predicted: yawl
# 551 | True: toucan | Predicted: toucan
# 552 | True: toucan | Predicted: yawl
# 553 | True: toucan | Predicted: yawl
# 554 | True: toucan | Predicted: yawl
# 555 | True: toucan | Predicted: yawl
# 556 | True: toucan | Predicted: yawl
# 557 | True: toucan | Predicted: yawl
# 558 | True: toucan | Predicted: toucan
# 559 | True: toucan | Predicted: yawl
# 560 | True: toucan | Predicted: yawl
# 561 | True: toucan | Predicted: yawl
# 562 | True: toucan | Predicted: yawl
# 563 | True: toucan | Predicted: yawl
# 564 | True: toucan | Predicted: yawl
# 565 | True: toucan | Predicted: yawl
# 566 | True: toucan | Predicted: yawl
# 567 | True: toucan | Predicted: yawl
# 568 | True: toucan | Predicted: yawl
# 569 | True: toucan | Predicted: yawl
# 570 | True: toucan | Predicted: yawl
# 571 | True: toucan | Predicted: yawl
# 572 | True: toucan | Predicted: toucan
# 573 | True: toucan | Predicted: yawl
# 574 | True: toucan | Predicted: yawl
# 575 | True: toucan | Predicted: toucan
# 576 | True: toucan | Predicted: yawl
# 577 | True: toucan | Predicted: yawl
# 578 | True: toucan | Predicted: toucan
# 579 | True: toucan | Predicted: yawl
# 580 | True: toucan | Predicted: yawl
# 581 | True: toucan | Predicted: yawl
# 582 | True: toucan | Predicted: yawl
# 583 | True: toucan | Predicted: yawl
# 584 | True: toucan | Predicted: yawl
# 585 | True: toucan | Predicted: yawl
# 586 | True: toucan | Predicted: yawl
# 587 | True: toucan | Predicted: yawl
# 588 | True: toucan | Predicted: yawl
# 589 | True: toucan | Predicted: toucan
# 590 | True: toucan | Predicted: yawl
# 591 | True: toucan | Predicted: yawl
# 592 | True: toucan | Predicted: yawl
# 593 | True: toucan | Predicted: yawl
# 594 | True: toucan | Predicted: yawl
# 595 | True: toucan | Predicted: yawl
# 596 | True: toucan | Predicted: yawl
# 597 | True: toucan | Predicted: yawl
# 598 | True: toucan | Predicted: yawl
# 599 | True: toucan | Predicted: yawl
# 600 | True: goose | Predicted: yawl
# 601 | True: goose | Predicted: goose
# 602 | True: goose | Predicted: goose
# 603 | True: goose | Predicted: goose
# 604 | True: goose | Predicted: yawl
# 605 | True: goose | Predicted: yawl
# 606 | True: goose | Predicted: goose
# 607 | True: goose | Predicted: goose
# 608 | True: goose | Predicted: yawl
# 609 | True: goose | Predicted: yawl
# 610 | True: goose | Predicted: goose
# 611 | True: goose | Predicted: yawl
# 612 | True: goose | Predicted: yawl
# 613 | True: goose | Predicted: goose
# 614 | True: goose | Predicted: goose
# 615 | True: goose | Predicted: goose
# 616 | True: goose | Predicted: goose
# 617 | True: goose | Predicted: goose
# 618 | True: goose | Predicted: yawl
# 619 | True: goose | Predicted: yawl
# 620 | True: goose | Predicted: goose
# 621 | True: goose | Predicted: goose
# 622 | True: goose | Predicted: goose
# 623 | True: goose | Predicted: goose
# 624 | True: goose | Predicted: goose
# 625 | True: goose | Predicted: yawl
# 626 | True: goose | Predicted: yawl
# 627 | True: goose | Predicted: yawl
# 628 | True: goose | Predicted: yawl
# 629 | True: goose | Predicted: goose
# 630 | True: goose | Predicted: goose
# 631 | True: goose | Predicted: goose
# 632 | True: goose | Predicted: yawl
# 633 | True: goose | Predicted: goose
# 634 | True: goose | Predicted: goose
# 635 | True: goose | Predicted: yawl
# 636 | True: goose | Predicted: yawl
# 637 | True: goose | Predicted: yawl
# 638 | True: goose | Predicted: yawl
# 639 | True: goose | Predicted: goose
# 640 | True: goose | Predicted: goose
# 641 | True: goose | Predicted: yawl
# 642 | True: goose | Predicted: yawl
# 643 | True: goose | Predicted: yawl
# 644 | True: goose | Predicted: yawl
# 645 | True: goose | Predicted: goose
# 646 | True: goose | Predicted: yawl
# 647 | True: goose | Predicted: goose
# 648 | True: goose | Predicted: yawl
# 649 | True: goose | Predicted: goose
# 650 | True: goose | Predicted: goose
# 651 | True: goose | Predicted: goose
# 652 | True: goose | Predicted: goose
# 653 | True: goose | Predicted: goose
# 654 | True: goose | Predicted: yawl
# 655 | True: goose | Predicted: goose
# 656 | True: goose | Predicted: goose
# 657 | True: goose | Predicted: goose
# 658 | True: goose | Predicted: goose
# 659 | True: goose | Predicted: yawl
# 660 | True: goose | Predicted: goose
# 661 | True: goose | Predicted: goose
# 662 | True: goose | Predicted: yawl
# 663 | True: goose | Predicted: yawl
# 664 | True: goose | Predicted: goose
# 665 | True: goose | Predicted: goose
# 666 | True: goose | Predicted: goose
# 667 | True: goose | Predicted: goose
# 668 | True: goose | Predicted: yawl
# 669 | True: goose | Predicted: goose
# 670 | True: goose | Predicted: goose
# 671 | True: goose | Predicted: goose
# 672 | True: goose | Predicted: goose
# 673 | True: goose | Predicted: goose
# 674 | True: goose | Predicted: goose
# 675 | True: goose | Predicted: goose
# 676 | True: goose | Predicted: yawl
# 677 | True: goose | Predicted: goose
# 678 | True: goose | Predicted: goose
# 679 | True: goose | Predicted: goose
# 680 | True: goose | Predicted: goose
# 681 | True: goose | Predicted: yawl
# 682 | True: goose | Predicted: goose
# 683 | True: goose | Predicted: yawl
# 684 | True: goose | Predicted: goose
# 685 | True: goose | Predicted: goose
# 686 | True: goose | Predicted: yawl
# 687 | True: goose | Predicted: goose
# 688 | True: goose | Predicted: goose
# 689 | True: goose | Predicted: goose
# 690 | True: goose | Predicted: yawl
# 691 | True: goose | Predicted: goose
# 692 | True: goose | Predicted: yawl
# 693 | True: goose | Predicted: yawl
# 694 | True: goose | Predicted: goose
# 695 | True: goose | Predicted: ashcan
# 696 | True: goose | Predicted: goose
# 697 | True: goose | Predicted: yawl
# 698 | True: goose | Predicted: goose
# 699 | True: goose | Predicted: goose
# 700 | True: jellyfish | Predicted: yawl
# 701 | True: jellyfish | Predicted: coral_reef
# 702 | True: jellyfish | Predicted: file
# 703 | True: jellyfish | Predicted: jellyfish
# 704 | True: jellyfish | Predicted: yawl
# 705 | True: jellyfish | Predicted: file
# 706 | True: jellyfish | Predicted: reel
# 707 | True: jellyfish | Predicted: yawl
# 708 | True: jellyfish | Predicted: stage
# 709 | True: jellyfish | Predicted: reel
# 710 | True: jellyfish | Predicted: yawl
# 711 | True: jellyfish | Predicted: jellyfish
# 712 | True: jellyfish | Predicted: coral_reef
# 713 | True: jellyfish | Predicted: frying_pan
# 714 | True: jellyfish | Predicted: yawl
# 715 | True: jellyfish | Predicted: yawl
# 716 | True: jellyfish | Predicted: yawl
# 717 | True: jellyfish | Predicted: ashcan
# 718 | True: jellyfish | Predicted: reel
# 719 | True: jellyfish | Predicted: stage
# 720 | True: jellyfish | Predicted: file
# 721 | True: jellyfish | Predicted: coral_reef
# 722 | True: jellyfish | Predicted: yawl
# 723 | True: jellyfish | Predicted: reel
# 724 | True: jellyfish | Predicted: ashcan
# 725 | True: jellyfish | Predicted: jellyfish
# 726 | True: jellyfish | Predicted: yawl
# 727 | True: jellyfish | Predicted: coral_reef
# 728 | True: jellyfish | Predicted: file
# 729 | True: jellyfish | Predicted: ashcan
# 730 | True: jellyfish | Predicted: coral_reef
# 731 | True: jellyfish | Predicted: yawl
# 732 | True: jellyfish | Predicted: coral_reef
# 733 | True: jellyfish | Predicted: file
# 734 | True: jellyfish | Predicted: coral_reef
# 735 | True: jellyfish | Predicted: jellyfish
# 736 | True: jellyfish | Predicted: yawl
# 737 | True: jellyfish | Predicted: yawl
# 738 | True: jellyfish | Predicted: dome
# 739 | True: jellyfish | Predicted: yawl
# 740 | True: jellyfish | Predicted: reel
# 741 | True: jellyfish | Predicted: frying_pan
# 742 | True: jellyfish | Predicted: yawl
# 743 | True: jellyfish | Predicted: coral_reef
# 744 | True: jellyfish | Predicted: yawl
# 745 | True: jellyfish | Predicted: jellyfish
# 746 | True: jellyfish | Predicted: yawl
# 747 | True: jellyfish | Predicted: tank
# 748 | True: jellyfish | Predicted: reel
# 749 | True: jellyfish | Predicted: reel
# 750 | True: jellyfish | Predicted: reel
# 751 | True: jellyfish | Predicted: yawl
# 752 | True: jellyfish | Predicted: jellyfish
# 753 | True: jellyfish | Predicted: yawl
# 754 | True: jellyfish | Predicted: file
# 755 | True: jellyfish | Predicted: rock_beauty
# 756 | True: jellyfish | Predicted: reel
# 757 | True: jellyfish | Predicted: coral_reef
# 758 | True: jellyfish | Predicted: ashcan
# 759 | True: jellyfish | Predicted: yawl
# 760 | True: jellyfish | Predicted: ashcan
# 761 | True: jellyfish | Predicted: yawl
# 762 | True: jellyfish | Predicted: jellyfish
# 763 | True: jellyfish | Predicted: yawl
# 764 | True: jellyfish | Predicted: coral_reef
# 765 | True: jellyfish | Predicted: coral_reef
# 766 | True: jellyfish | Predicted: ashcan
# 767 | True: jellyfish | Predicted: yawl
# 768 | True: jellyfish | Predicted: jellyfish
# 769 | True: jellyfish | Predicted: jellyfish
# 770 | True: jellyfish | Predicted: file
# 771 | True: jellyfish | Predicted: yawl
# 772 | True: jellyfish | Predicted: jellyfish
# 773 | True: jellyfish | Predicted: yawl
# 774 | True: jellyfish | Predicted: coral_reef
# 775 | True: jellyfish | Predicted: reel
# 776 | True: jellyfish | Predicted: yawl
# 777 | True: jellyfish | Predicted: yawl
# 778 | True: jellyfish | Predicted: yawl
# 779 | True: jellyfish | Predicted: yawl
# 780 | True: jellyfish | Predicted: yawl
# 781 | True: jellyfish | Predicted: jellyfish
# 782 | True: jellyfish | Predicted: yawl
# 783 | True: jellyfish | Predicted: yawl
# 784 | True: jellyfish | Predicted: file
# 785 | True: jellyfish | Predicted: jellyfish
# 786 | True: jellyfish | Predicted: jellyfish
# 787 | True: jellyfish | Predicted: yawl
# 788 | True: jellyfish | Predicted: yawl
# 789 | True: jellyfish | Predicted: file
# 790 | True: jellyfish | Predicted: yawl
# 791 | True: jellyfish | Predicted: file
# 792 | True: jellyfish | Predicted: yawl
# 793 | True: jellyfish | Predicted: jellyfish
# 794 | True: jellyfish | Predicted: yawl
# 795 | True: jellyfish | Predicted: yawl
# 796 | True: jellyfish | Predicted: jellyfish
# 797 | True: jellyfish | Predicted: coral_reef
# 798 | True: jellyfish | Predicted: yawl
# 799 | True: jellyfish | Predicted: yawl
# 800 | True: nematode | Predicted: nematode
# 801 | True: nematode | Predicted: yawl
# 802 | True: nematode | Predicted: nematode
# 803 | True: nematode | Predicted: ear
# 804 | True: nematode | Predicted: nematode
# 805 | True: nematode | Predicted: ashcan
# 806 | True: nematode | Predicted: nematode
# 807 | True: nematode | Predicted: nematode
# 808 | True: nematode | Predicted: nematode
# 809 | True: nematode | Predicted: ashcan
# 810 | True: nematode | Predicted: nematode
# 811 | True: nematode | Predicted: yawl
# 812 | True: nematode | Predicted: ear
# 813 | True: nematode | Predicted: nematode
# 814 | True: nematode | Predicted: ear
# 815 | True: nematode | Predicted: ashcan
# 816 | True: nematode | Predicted: yawl
# 817 | True: nematode | Predicted: ear
# 818 | True: nematode | Predicted: ashcan
# 819 | True: nematode | Predicted: nematode
# 820 | True: nematode | Predicted: ear
# 821 | True: nematode | Predicted: nematode
# 822 | True: nematode | Predicted: nematode
# 823 | True: nematode | Predicted: ear
# 824 | True: nematode | Predicted: nematode
# 825 | True: nematode | Predicted: ashcan
# 826 | True: nematode | Predicted: nematode
# 827 | True: nematode | Predicted: ear
# 828 | True: nematode | Predicted: nematode
# 829 | True: nematode | Predicted: yawl
# 830 | True: nematode | Predicted: ear
# 831 | True: nematode | Predicted: yawl
# 832 | True: nematode | Predicted: ear
# 833 | True: nematode | Predicted: nematode
# 834 | True: nematode | Predicted: nematode
# 835 | True: nematode | Predicted: nematode
# 836 | True: nematode | Predicted: nematode
# 837 | True: nematode | Predicted: nematode
# 838 | True: nematode | Predicted: nematode
# 839 | True: nematode | Predicted: nematode
# 840 | True: nematode | Predicted: file
# 841 | True: nematode | Predicted: nematode
# 842 | True: nematode | Predicted: yawl
# 843 | True: nematode | Predicted: yawl
# 844 | True: nematode | Predicted: yawl
# 845 | True: nematode | Predicted: yawl
# 846 | True: nematode | Predicted: nematode
# 847 | True: nematode | Predicted: nematode
# 848 | True: nematode | Predicted: nematode
# 849 | True: nematode | Predicted: yawl
# 850 | True: nematode | Predicted: yawl
# 851 | True: nematode | Predicted: nematode
# 852 | True: nematode | Predicted: hair_slide
# 853 | True: nematode | Predicted: yawl
# 854 | True: nematode | Predicted: file
# 855 | True: nematode | Predicted: ashcan
# 856 | True: nematode | Predicted: nematode
# 857 | True: nematode | Predicted: yawl
# 858 | True: nematode | Predicted: nematode
# 859 | True: nematode | Predicted: nematode
# 860 | True: nematode | Predicted: ashcan
# 861 | True: nematode | Predicted: nematode
# 862 | True: nematode | Predicted: ashcan
# 863 | True: nematode | Predicted: nematode
# 864 | True: nematode | Predicted: nematode
# 865 | True: nematode | Predicted: ashcan
# 866 | True: nematode | Predicted: yawl
# 867 | True: nematode | Predicted: nematode
# 868 | True: nematode | Predicted: nematode
# 869 | True: nematode | Predicted: nematode
# 870 | True: nematode | Predicted: file
# 871 | True: nematode | Predicted: nematode
# 872 | True: nematode | Predicted: yawl
# 873 | True: nematode | Predicted: yawl
# 874 | True: nematode | Predicted: nematode
# 875 | True: nematode | Predicted: hair_slide
# 876 | True: nematode | Predicted: yawl
# 877 | True: nematode | Predicted: nematode
# 878 | True: nematode | Predicted: hair_slide
# 879 | True: nematode | Predicted: nematode
# 880 | True: nematode | Predicted: file
# 881 | True: nematode | Predicted: yawl
# 882 | True: nematode | Predicted: ashcan
# 883 | True: nematode | Predicted: nematode
# 884 | True: nematode | Predicted: ashcan
# 885 | True: nematode | Predicted: nematode
# 886 | True: nematode | Predicted: nematode
# 887 | True: nematode | Predicted: ear
# 888 | True: nematode | Predicted: file
# 889 | True: nematode | Predicted: nematode
# 890 | True: nematode | Predicted: nematode
# 891 | True: nematode | Predicted: nematode
# 892 | True: nematode | Predicted: ashcan
# 893 | True: nematode | Predicted: ashcan
# 894 | True: nematode | Predicted: nematode
# 895 | True: nematode | Predicted: file
# 896 | True: nematode | Predicted: nematode
# 897 | True: nematode | Predicted: ear
# 898 | True: nematode | Predicted: nematode
# 899 | True: nematode | Predicted: nematode
# 900 | True: king_crab | Predicted: king_crab
# 901 | True: king_crab | Predicted: king_crab
# 902 | True: king_crab | Predicted: king_crab
# 903 | True: king_crab | Predicted: king_crab
# 904 | True: king_crab | Predicted: yawl
# 905 | True: king_crab | Predicted: king_crab
# 906 | True: king_crab | Predicted: king_crab
# 907 | True: king_crab | Predicted: king_crab
# 908 | True: king_crab | Predicted: king_crab
# 909 | True: king_crab | Predicted: king_crab
# 910 | True: king_crab | Predicted: king_crab
# 911 | True: king_crab | Predicted: king_crab
# 912 | True: king_crab | Predicted: king_crab
# 913 | True: king_crab | Predicted: king_crab
# 914 | True: king_crab | Predicted: yawl
# 915 | True: king_crab | Predicted: king_crab
# 916 | True: king_crab | Predicted: king_crab
# 917 | True: king_crab | Predicted: king_crab
# 918 | True: king_crab | Predicted: king_crab
# 919 | True: king_crab | Predicted: king_crab
# 920 | True: king_crab | Predicted: king_crab
# 921 | True: king_crab | Predicted: king_crab
# 922 | True: king_crab | Predicted: king_crab
# 923 | True: king_crab | Predicted: king_crab
# 924 | True: king_crab | Predicted: king_crab
# 925 | True: king_crab | Predicted: king_crab
# 926 | True: king_crab | Predicted: king_crab
# 927 | True: king_crab | Predicted: king_crab
# 928 | True: king_crab | Predicted: king_crab
# 929 | True: king_crab | Predicted: king_crab
# 930 | True: king_crab | Predicted: king_crab
# 931 | True: king_crab | Predicted: king_crab
# 932 | True: king_crab | Predicted: king_crab
# 933 | True: king_crab | Predicted: king_crab
# 934 | True: king_crab | Predicted: king_crab
# 935 | True: king_crab | Predicted: king_crab
# 936 | True: king_crab | Predicted: king_crab
# 937 | True: king_crab | Predicted: king_crab
# 938 | True: king_crab | Predicted: king_crab
# 939 | True: king_crab | Predicted: king_crab
# 940 | True: king_crab | Predicted: king_crab
# 941 | True: king_crab | Predicted: king_crab
# 942 | True: king_crab | Predicted: king_crab
# 943 | True: king_crab | Predicted: yawl
# 944 | True: king_crab | Predicted: king_crab
# 945 | True: king_crab | Predicted: king_crab
# 946 | True: king_crab | Predicted: king_crab
# 947 | True: king_crab | Predicted: king_crab
# 948 | True: king_crab | Predicted: king_crab
# 949 | True: king_crab | Predicted: king_crab
# 950 | True: king_crab | Predicted: king_crab
# 951 | True: king_crab | Predicted: king_crab
# 952 | True: king_crab | Predicted: king_crab
# 953 | True: king_crab | Predicted: king_crab
# 954 | True: king_crab | Predicted: king_crab
# 955 | True: king_crab | Predicted: king_crab
# 956 | True: king_crab | Predicted: king_crab
# 957 | True: king_crab | Predicted: king_crab
# 958 | True: king_crab | Predicted: king_crab
# 959 | True: king_crab | Predicted: king_crab
# 960 | True: king_crab | Predicted: king_crab
# 961 | True: king_crab | Predicted: king_crab
# 962 | True: king_crab | Predicted: king_crab
# 963 | True: king_crab | Predicted: king_crab
# 964 | True: king_crab | Predicted: king_crab
# 965 | True: king_crab | Predicted: king_crab
# 966 | True: king_crab | Predicted: king_crab
# 967 | True: king_crab | Predicted: king_crab
# 968 | True: king_crab | Predicted: yawl
# 969 | True: king_crab | Predicted: king_crab
# 970 | True: king_crab | Predicted: king_crab
# 971 | True: king_crab | Predicted: king_crab
# 972 | True: king_crab | Predicted: yawl
# 973 | True: king_crab | Predicted: king_crab
# 974 | True: king_crab | Predicted: king_crab
# 975 | True: king_crab | Predicted: king_crab
# 976 | True: king_crab | Predicted: king_crab
# 977 | True: king_crab | Predicted: king_crab
# 978 | True: king_crab | Predicted: king_crab
# 979 | True: king_crab | Predicted: king_crab
# 980 | True: king_crab | Predicted: yawl
# 981 | True: king_crab | Predicted: king_crab
# 982 | True: king_crab | Predicted: yawl
# 983 | True: king_crab | Predicted: king_crab
# 984 | True: king_crab | Predicted: yawl
# 985 | True: king_crab | Predicted: king_crab
# 986 | True: king_crab | Predicted: king_crab
# 987 | True: king_crab | Predicted: king_crab
# 988 | True: king_crab | Predicted: king_crab
# 989 | True: king_crab | Predicted: king_crab
# 990 | True: king_crab | Predicted: yawl
# 991 | True: king_crab | Predicted: yawl
# 992 | True: king_crab | Predicted: yawl
# 993 | True: king_crab | Predicted: king_crab
# 994 | True: king_crab | Predicted: consomme
# 995 | True: king_crab | Predicted: king_crab
# 996 | True: king_crab | Predicted: king_crab
# 997 | True: king_crab | Predicted: king_crab
# 998 | True: king_crab | Predicted: yawl
# 999 | True: king_crab | Predicted: king_crab
# 1000 | True: dugong | Predicted: yawl
# 1001 | True: dugong | Predicted: yawl
# 1002 | True: dugong | Predicted: yawl
# 1003 | True: dugong | Predicted: dugong
# 1004 | True: dugong | Predicted: yawl
# 1005 | True: dugong | Predicted: yawl
# 1006 | True: dugong | Predicted: dugong
# 1007 | True: dugong | Predicted: yawl
# 1008 | True: dugong | Predicted: yawl
# 1009 | True: dugong | Predicted: dugong
# 1010 | True: dugong | Predicted: dugong
# 1011 | True: dugong | Predicted: dugong
# 1012 | True: dugong | Predicted: snorkel
# 1013 | True: dugong | Predicted: yawl
# 1014 | True: dugong | Predicted: yawl
# 1015 | True: dugong | Predicted: yawl
# 1016 | True: dugong | Predicted: yawl
# 1017 | True: dugong | Predicted: yawl
# 1018 | True: dugong | Predicted: dugong
# 1019 | True: dugong | Predicted: yawl
# 1020 | True: dugong | Predicted: yawl
# 1021 | True: dugong | Predicted: dugong
# 1022 | True: dugong | Predicted: yawl
# 1023 | True: dugong | Predicted: yawl
# 1024 | True: dugong | Predicted: dugong
# 1025 | True: dugong | Predicted: yawl
# 1026 | True: dugong | Predicted: yawl
# 1027 | True: dugong | Predicted: yawl
# 1028 | True: dugong | Predicted: dugong
# 1029 | True: dugong | Predicted: yawl
# 1030 | True: dugong | Predicted: yawl
# 1031 | True: dugong | Predicted: dugong
# 1032 | True: dugong | Predicted: yawl
# 1033 | True: dugong | Predicted: coral_reef
# 1034 | True: dugong | Predicted: yawl
# 1035 | True: dugong | Predicted: dugong
# 1036 | True: dugong | Predicted: dugong
# 1037 | True: dugong | Predicted: yawl
# 1038 | True: dugong | Predicted: yawl
# 1039 | True: dugong | Predicted: yawl
# 1040 | True: dugong | Predicted: dugong
# 1041 | True: dugong | Predicted: yawl
# 1042 | True: dugong | Predicted: yawl
# 1043 | True: dugong | Predicted: dugong
# 1044 | True: dugong | Predicted: dugong
# 1045 | True: dugong | Predicted: yawl
# 1046 | True: dugong | Predicted: yawl
# 1047 | True: dugong | Predicted: yawl
# 1048 | True: dugong | Predicted: dugong
# 1049 | True: dugong | Predicted: coral_reef
# 1050 | True: dugong | Predicted: yawl
# 1051 | True: dugong | Predicted: green_mamba
# 1052 | True: dugong | Predicted: dugong
# 1053 | True: dugong | Predicted: yawl
# 1054 | True: dugong | Predicted: yawl
# 1055 | True: dugong | Predicted: dugong
# 1056 | True: dugong | Predicted: dugong
# 1057 | True: dugong | Predicted: yawl
# 1058 | True: dugong | Predicted: dugong
# 1059 | True: dugong | Predicted: yawl
# 1060 | True: dugong | Predicted: yawl
# 1061 | True: dugong | Predicted: dugong
# 1062 | True: dugong | Predicted: yawl
# 1063 | True: dugong | Predicted: yawl
# 1064 | True: dugong | Predicted: yawl
# 1065 | True: dugong | Predicted: yawl
# 1066 | True: dugong | Predicted: yawl
# 1067 | True: dugong | Predicted: yawl
# 1068 | True: dugong | Predicted: yawl
# 1069 | True: dugong | Predicted: dugong
# 1070 | True: dugong | Predicted: dugong
# 1071 | True: dugong | Predicted: yawl
# 1072 | True: dugong | Predicted: dugong
# 1073 | True: dugong | Predicted: yawl
# 1074 | True: dugong | Predicted: yawl
# 1075 | True: dugong | Predicted: dugong
# 1076 | True: dugong | Predicted: yawl
# 1077 | True: dugong | Predicted: yawl
# 1078 | True: dugong | Predicted: dugong
# 1079 | True: dugong | Predicted: yawl
# 1080 | True: dugong | Predicted: yawl
# 1081 | True: dugong | Predicted: yawl
# 1082 | True: dugong | Predicted: yawl
# 1083 | True: dugong | Predicted: yawl
# 1084 | True: dugong | Predicted: yawl
# 1085 | True: dugong | Predicted: yawl
# 1086 | True: dugong | Predicted: yawl
# 1087 | True: dugong | Predicted: yawl
# 1088 | True: dugong | Predicted: yawl
# 1089 | True: dugong | Predicted: yawl
# 1090 | True: dugong | Predicted: yawl
# 1091 | True: dugong | Predicted: yawl
# 1092 | True: dugong | Predicted: yawl
# 1093 | True: dugong | Predicted: dugong
# 1094 | True: dugong | Predicted: dugong
# 1095 | True: dugong | Predicted: yawl
# 1096 | True: dugong | Predicted: yawl
# 1097 | True: dugong | Predicted: yawl
# 1098 | True: dugong | Predicted: dugong
# 1099 | True: dugong | Predicted: yawl
# 1100 | True: Walker_hound | Predicted: yawl
# 1101 | True: Walker_hound | Predicted: Walker_hound
# 1102 | True: Walker_hound | Predicted: Walker_hound
# 1103 | True: Walker_hound | Predicted: African_hunting_dog
# 1104 | True: Walker_hound | Predicted: yawl
# 1105 | True: Walker_hound | Predicted: yawl
# 1106 | True: Walker_hound | Predicted: yawl
# 1107 | True: Walker_hound | Predicted: yawl
# 1108 | True: Walker_hound | Predicted: Walker_hound
# 1109 | True: Walker_hound | Predicted: yawl
# 1110 | True: Walker_hound | Predicted: Walker_hound
# 1111 | True: Walker_hound | Predicted: Walker_hound
# 1112 | True: Walker_hound | Predicted: Walker_hound
# 1113 | True: Walker_hound | Predicted: Walker_hound
# 1114 | True: Walker_hound | Predicted: yawl
# 1115 | True: Walker_hound | Predicted: yawl
# 1116 | True: Walker_hound | Predicted: yawl
# 1117 | True: Walker_hound | Predicted: yawl
# 1118 | True: Walker_hound | Predicted: yawl
# 1119 | True: Walker_hound | Predicted: Walker_hound
# 1120 | True: Walker_hound | Predicted: Walker_hound
# 1121 | True: Walker_hound | Predicted: yawl
# 1122 | True: Walker_hound | Predicted: African_hunting_dog
# 1123 | True: Walker_hound | Predicted: Walker_hound
# 1124 | True: Walker_hound | Predicted: Walker_hound
# 1125 | True: Walker_hound | Predicted: yawl
# 1126 | True: Walker_hound | Predicted: yawl
# 1127 | True: Walker_hound | Predicted: Walker_hound
# 1128 | True: Walker_hound | Predicted: Walker_hound
# 1129 | True: Walker_hound | Predicted: Walker_hound
# 1130 | True: Walker_hound | Predicted: Walker_hound
# 1131 | True: Walker_hound | Predicted: Walker_hound
# 1132 | True: Walker_hound | Predicted: Walker_hound
# 1133 | True: Walker_hound | Predicted: yawl
# 1134 | True: Walker_hound | Predicted: yawl
# 1135 | True: Walker_hound | Predicted: Walker_hound
# 1136 | True: Walker_hound | Predicted: yawl
# 1137 | True: Walker_hound | Predicted: boxer
# 1138 | True: Walker_hound | Predicted: African_hunting_dog
# 1139 | True: Walker_hound | Predicted: yawl
# 1140 | True: Walker_hound | Predicted: yawl
# ...
# 9605 | True: cliff | Predicted: yawl
# 9606 | True: cliff | Predicted: rock_beauty
# 9607 | True: cliff | Predicted: cliff
# 9608 | True: cliff | Predicted: yawl
# 9609 | True: cliff | Predicted: rock_beauty
# 9610 | True: cliff | Predicted: rock_beauty
# 9611 | True: cliff | Predicted: rock_beauty
# 9612 | True: cliff | Predicted: yawl
# 9613 | True: cliff | Predicted: rock_beauty
# 9614 | True: cliff | Predicted: cliff
# 9615 | True: cliff | Predicted: yawl
# 9616 | True: cliff | Predicted: yawl
# 9617 | True: cliff | Predicted: yawl
# 9618 | True: cliff | Predicted: yawl
# 9619 | True: cliff | Predicted: yawl
# 9620 | True: cliff | Predicted: yawl
# 9621 | True: cliff | Predicted: rock_beauty
# 9622 | True: cliff | Predicted: file
# 9623 | True: cliff | Predicted: rock_beauty
# 9624 | True: cliff | Predicted: yawl
# 9625 | True: cliff | Predicted: yawl
# 9626 | True: cliff | Predicted: yawl
# 9627 | True: cliff | Predicted: yawl
# 9628 | True: cliff | Predicted: yawl
# 9629 | True: cliff | Predicted: yawl
# 9630 | True: cliff | Predicted: rock_beauty
# 9631 | True: cliff | Predicted: rock_beauty
# 9632 | True: cliff | Predicted: yawl
# 9633 | True: cliff | Predicted: yawl
# 9634 | True: cliff | Predicted: rock_beauty
# 9635 | True: cliff | Predicted: yawl
# 9636 | True: cliff | Predicted: cliff
# 9637 | True: cliff | Predicted: yawl
# 9638 | True: cliff | Predicted: yawl
# 9639 | True: cliff | Predicted: rock_beauty
# 9640 | True: cliff | Predicted: rock_beauty
# 9641 | True: cliff | Predicted: cliff
# 9642 | True: cliff | Predicted: yawl
# 9643 | True: cliff | Predicted: yawl
# 9644 | True: cliff | Predicted: rock_beauty
# 9645 | True: cliff | Predicted: cliff
# 9646 | True: cliff | Predicted: yawl
# 9647 | True: cliff | Predicted: fire_screen
# 9648 | True: cliff | Predicted: yawl
# 9649 | True: cliff | Predicted: yawl
# 9650 | True: cliff | Predicted: rock_beauty
# 9651 | True: cliff | Predicted: yawl
# 9652 | True: cliff | Predicted: rock_beauty
# 9653 | True: cliff | Predicted: cliff
# 9654 | True: cliff | Predicted: cliff
# 9655 | True: cliff | Predicted: yawl
# 9656 | True: cliff | Predicted: stage
# 9657 | True: cliff | Predicted: yawl
# 9658 | True: cliff | Predicted: yawl
# 9659 | True: cliff | Predicted: yawl
# 9660 | True: cliff | Predicted: rock_beauty
# 9661 | True: cliff | Predicted: yawl
# 9662 | True: cliff | Predicted: rock_beauty
# 9663 | True: cliff | Predicted: rock_beauty
# 9664 | True: cliff | Predicted: yawl
# 9665 | True: cliff | Predicted: yawl
# 9666 | True: cliff | Predicted: yawl
# 9667 | True: cliff | Predicted: stage
# 9668 | True: cliff | Predicted: yawl
# 9669 | True: cliff | Predicted: yawl
# 9670 | True: cliff | Predicted: cliff
# 9671 | True: cliff | Predicted: yawl
# 9672 | True: cliff | Predicted: cliff
# 9673 | True: cliff | Predicted: rock_beauty
# 9674 | True: cliff | Predicted: ashcan
# 9675 | True: cliff | Predicted: yawl
# 9676 | True: cliff | Predicted: cliff
# 9677 | True: cliff | Predicted: yawl
# 9678 | True: cliff | Predicted: yawl
# 9679 | True: cliff | Predicted: yawl
# 9680 | True: cliff | Predicted: yawl
# 9681 | True: cliff | Predicted: cliff
# 9682 | True: cliff | Predicted: rock_beauty
# 9683 | True: cliff | Predicted: stage
# 9684 | True: cliff | Predicted: rock_beauty
# 9685 | True: cliff | Predicted: yawl
# 9686 | True: cliff | Predicted: yawl
# 9687 | True: cliff | Predicted: rock_beauty
# 9688 | True: cliff | Predicted: yawl
# 9689 | True: cliff | Predicted: file
# 9690 | True: cliff | Predicted: yawl
# 9691 | True: cliff | Predicted: yawl
# 9692 | True: cliff | Predicted: yawl
# 9693 | True: cliff | Predicted: yawl
# 9694 | True: cliff | Predicted: rock_beauty
# 9695 | True: cliff | Predicted: rock_beauty
# 9696 | True: cliff | Predicted: yawl
# 9697 | True: cliff | Predicted: yawl
# 9698 | True: cliff | Predicted: yawl
# 9699 | True: cliff | Predicted: yawl
# 9700 | True: coral_reef | Predicted: coral_reef
# 9701 | True: coral_reef | Predicted: coral_reef
# 9702 | True: coral_reef | Predicted: coral_reef
# 9703 | True: coral_reef | Predicted: coral_reef
# 9704 | True: coral_reef | Predicted: coral_reef
# 9705 | True: coral_reef | Predicted: coral_reef
# 9706 | True: coral_reef | Predicted: yawl
# 9707 | True: coral_reef | Predicted: coral_reef
# 9708 | True: coral_reef | Predicted: coral_reef
# 9709 | True: coral_reef | Predicted: coral_reef
# 9710 | True: coral_reef | Predicted: coral_reef
# 9711 | True: coral_reef | Predicted: coral_reef
# 9712 | True: coral_reef | Predicted: coral_reef
# 9713 | True: coral_reef | Predicted: coral_reef
# 9714 | True: coral_reef | Predicted: yawl
# 9715 | True: coral_reef | Predicted: coral_reef
# 9716 | True: coral_reef | Predicted: coral_reef
# 9717 | True: coral_reef | Predicted: coral_reef
# 9718 | True: coral_reef | Predicted: yawl
# 9719 | True: coral_reef | Predicted: yawl
# 9720 | True: coral_reef | Predicted: coral_reef
# 9721 | True: coral_reef | Predicted: coral_reef
# 9722 | True: coral_reef | Predicted: coral_reef
# 9723 | True: coral_reef | Predicted: coral_reef
# 9724 | True: coral_reef | Predicted: coral_reef
# 9725 | True: coral_reef | Predicted: coral_reef
# 9726 | True: coral_reef | Predicted: coral_reef
# 9727 | True: coral_reef | Predicted: coral_reef
# 9728 | True: coral_reef | Predicted: coral_reef
# 9729 | True: coral_reef | Predicted: coral_reef
# 9730 | True: coral_reef | Predicted: coral_reef
# 9731 | True: coral_reef | Predicted: coral_reef
# 9732 | True: coral_reef | Predicted: coral_reef
# 9733 | True: coral_reef | Predicted: dishrag
# 9734 | True: coral_reef | Predicted: yawl
# 9735 | True: coral_reef | Predicted: coral_reef
# 9736 | True: coral_reef | Predicted: coral_reef
# 9737 | True: coral_reef | Predicted: coral_reef
# 9738 | True: coral_reef | Predicted: snorkel
# 9739 | True: coral_reef | Predicted: coral_reef
# 9740 | True: coral_reef | Predicted: coral_reef
# 9741 | True: coral_reef | Predicted: coral_reef
# 9742 | True: coral_reef | Predicted: coral_reef
# 9743 | True: coral_reef | Predicted: yawl
# 9744 | True: coral_reef | Predicted: coral_reef
# 9745 | True: coral_reef | Predicted: coral_reef
# 9746 | True: coral_reef | Predicted: coral_reef
# 9747 | True: coral_reef | Predicted: coral_reef
# 9748 | True: coral_reef | Predicted: coral_reef
# 9749 | True: coral_reef | Predicted: coral_reef
# 9750 | True: coral_reef | Predicted: coral_reef
# 9751 | True: coral_reef | Predicted: coral_reef
# 9752 | True: coral_reef | Predicted: coral_reef
# 9753 | True: coral_reef | Predicted: coral_reef
# 9754 | True: coral_reef | Predicted: coral_reef
# 9755 | True: coral_reef | Predicted: coral_reef
# 9756 | True: coral_reef | Predicted: coral_reef
# 9757 | True: coral_reef | Predicted: coral_reef
# 9758 | True: coral_reef | Predicted: coral_reef
# 9759 | True: coral_reef | Predicted: coral_reef
# 9760 | True: coral_reef | Predicted: coral_reef
# 9761 | True: coral_reef | Predicted: coral_reef
# 9762 | True: coral_reef | Predicted: coral_reef
# 9763 | True: coral_reef | Predicted: coral_reef
# 9764 | True: coral_reef | Predicted: coral_reef
# 9765 | True: coral_reef | Predicted: coral_reef
# 9766 | True: coral_reef | Predicted: coral_reef
# 9767 | True: coral_reef | Predicted: coral_reef
# 9768 | True: coral_reef | Predicted: dishrag
# 9769 | True: coral_reef | Predicted: coral_reef
# 9770 | True: coral_reef | Predicted: coral_reef
# 9771 | True: coral_reef | Predicted: coral_reef
# 9772 | True: coral_reef | Predicted: coral_reef
# 9773 | True: coral_reef | Predicted: coral_reef
# 9774 | True: coral_reef | Predicted: coral_reef
# 9775 | True: coral_reef | Predicted: coral_reef
# 9776 | True: coral_reef | Predicted: coral_reef
# 9777 | True: coral_reef | Predicted: coral_reef
# 9778 | True: coral_reef | Predicted: coral_reef
# 9779 | True: coral_reef | Predicted: coral_reef
# 9780 | True: coral_reef | Predicted: coral_reef
# 9781 | True: coral_reef | Predicted: coral_reef
# 9782 | True: coral_reef | Predicted: coral_reef
# 9783 | True: coral_reef | Predicted: file
# 9784 | True: coral_reef | Predicted: coral_reef
# 9785 | True: coral_reef | Predicted: coral_reef
# 9786 | True: coral_reef | Predicted: coral_reef
# 9787 | True: coral_reef | Predicted: coral_reef
# 9788 | True: coral_reef | Predicted: coral_reef
# 9789 | True: coral_reef | Predicted: coral_reef
# 9790 | True: coral_reef | Predicted: coral_reef
# 9791 | True: coral_reef | Predicted: coral_reef
# 9792 | True: coral_reef | Predicted: coral_reef
# 9793 | True: coral_reef | Predicted: coral_reef
# 9794 | True: coral_reef | Predicted: coral_reef
# 9795 | True: coral_reef | Predicted: coral_reef
# 9796 | True: coral_reef | Predicted: coral_reef
# 9797 | True: coral_reef | Predicted: coral_reef
# 9798 | True: coral_reef | Predicted: coral_reef
# 9799 | True: coral_reef | Predicted: yawl
# 9800 | True: bolete | Predicted: ashcan
# 9801 | True: bolete | Predicted: ashcan
# 9802 | True: bolete | Predicted: bolete
# 9803 | True: bolete | Predicted: ashcan
# 9804 | True: bolete | Predicted: ashcan
# 9805 | True: bolete | Predicted: bolete
# 9806 | True: bolete | Predicted: bolete
# 9807 | True: bolete | Predicted: yawl
# 9808 | True: bolete | Predicted: bolete
# 9809 | True: bolete | Predicted: bolete
# 9810 | True: bolete | Predicted: ashcan
# 9811 | True: bolete | Predicted: bolete
# 9812 | True: bolete | Predicted: ashcan
# 9813 | True: bolete | Predicted: ashcan
# 9814 | True: bolete | Predicted: bolete
# 9815 | True: bolete | Predicted: ashcan
# 9816 | True: bolete | Predicted: bolete
# 9817 | True: bolete | Predicted: bolete
# 9818 | True: bolete | Predicted: bolete
# 9819 | True: bolete | Predicted: file
# 9820 | True: bolete | Predicted: ashcan
# 9821 | True: bolete | Predicted: bolete
# 9822 | True: bolete | Predicted: ashcan
# 9823 | True: bolete | Predicted: ashcan
# 9824 | True: bolete | Predicted: bolete
# 9825 | True: bolete | Predicted: ashcan
# 9826 | True: bolete | Predicted: ashcan
# 9827 | True: bolete | Predicted: ashcan
# 9828 | True: bolete | Predicted: ashcan
# 9829 | True: bolete | Predicted: ashcan
# 9830 | True: bolete | Predicted: yawl
# 9831 | True: bolete | Predicted: bolete
# 9832 | True: bolete | Predicted: ashcan
# 9833 | True: bolete | Predicted: bolete
# 9834 | True: bolete | Predicted: bolete
# 9835 | True: bolete | Predicted: bolete
# 9836 | True: bolete | Predicted: bolete
# 9837 | True: bolete | Predicted: bolete
# 9838 | True: bolete | Predicted: ashcan
# 9839 | True: bolete | Predicted: bolete
# 9840 | True: bolete | Predicted: bolete
# 9841 | True: bolete | Predicted: bolete
# 9842 | True: bolete | Predicted: bolete
# 9843 | True: bolete | Predicted: bolete
# 9844 | True: bolete | Predicted: ashcan
# 9845 | True: bolete | Predicted: ashcan
# 9846 | True: bolete | Predicted: yawl
# 9847 | True: bolete | Predicted: ashcan
# 9848 | True: bolete | Predicted: bolete
# 9849 | True: bolete | Predicted: ashcan
# 9850 | True: bolete | Predicted: ashcan
# 9851 | True: bolete | Predicted: ashcan
# 9852 | True: bolete | Predicted: ashcan
# 9853 | True: bolete | Predicted: bolete
# 9854 | True: bolete | Predicted: bolete
# 9855 | True: bolete | Predicted: ashcan
# 9856 | True: bolete | Predicted: ashcan
# 9857 | True: bolete | Predicted: bolete
# 9858 | True: bolete | Predicted: bolete
# 9859 | True: bolete | Predicted: ashcan
# 9860 | True: bolete | Predicted: ashcan
# 9861 | True: bolete | Predicted: bolete
# 9862 | True: bolete | Predicted: bolete
# 9863 | True: bolete | Predicted: ashcan
# 9864 | True: bolete | Predicted: ashcan
# 9865 | True: bolete | Predicted: ashcan
# 9866 | True: bolete | Predicted: yawl
# 9867 | True: bolete | Predicted: ashcan
# 9868 | True: bolete | Predicted: ashcan
# 9869 | True: bolete | Predicted: bolete
# 9870 | True: bolete | Predicted: bolete
# 9871 | True: bolete | Predicted: ashcan
# 9872 | True: bolete | Predicted: bolete
# 9873 | True: bolete | Predicted: bolete
# 9874 | True: bolete | Predicted: bolete
# 9875 | True: bolete | Predicted: ashcan
# 9876 | True: bolete | Predicted: ashcan
# 9877 | True: bolete | Predicted: bolete
# 9878 | True: bolete | Predicted: bolete
# 9879 | True: bolete | Predicted: bolete
# 9880 | True: bolete | Predicted: yawl
# 9881 | True: bolete | Predicted: bolete
# 9882 | True: bolete | Predicted: bolete
# 9883 | True: bolete | Predicted: green_mamba
# 9884 | True: bolete | Predicted: ashcan
# 9885 | True: bolete | Predicted: bolete
# 9886 | True: bolete | Predicted: ashcan
# 9887 | True: bolete | Predicted: ashcan
# 9888 | True: bolete | Predicted: ashcan
# 9889 | True: bolete | Predicted: bolete
# 9890 | True: bolete | Predicted: bolete
# 9891 | True: bolete | Predicted: ashcan
# 9892 | True: bolete | Predicted: bolete
# 9893 | True: bolete | Predicted: bolete
# 9894 | True: bolete | Predicted: ashcan
# 9895 | True: bolete | Predicted: ashcan
# 9896 | True: bolete | Predicted: ashcan
# 9897 | True: bolete | Predicted: ashcan
# 9898 | True: bolete | Predicted: bolete
# 9899 | True: bolete | Predicted: bolete
# 9900 | True: ear | Predicted: yawl
# 9901 | True: ear | Predicted: yawl
# 9902 | True: ear | Predicted: yawl
# 9903 | True: ear | Predicted: yawl
# 9904 | True: ear | Predicted: yawl
# 9905 | True: ear | Predicted: yawl
# 9906 | True: ear | Predicted: yawl
# 9907 | True: ear | Predicted: yawl
# 9908 | True: ear | Predicted: yawl
# 9909 | True: ear | Predicted: yawl
# 9910 | True: ear | Predicted: yawl
# 9911 | True: ear | Predicted: yawl
# 9912 | True: ear | Predicted: yawl
# 9913 | True: ear | Predicted: yawl
# 9914 | True: ear | Predicted: yawl
# 9915 | True: ear | Predicted: file
# 9916 | True: ear | Predicted: yawl
# 9917 | True: ear | Predicted: yawl
# 9918 | True: ear | Predicted: yawl
# 9919 | True: ear | Predicted: yawl
# 9920 | True: ear | Predicted: yawl
# 9921 | True: ear | Predicted: yawl
# 9922 | True: ear | Predicted: yawl
# 9923 | True: ear | Predicted: file
# 9924 | True: ear | Predicted: ashcan
# 9925 | True: ear | Predicted: yawl
# 9926 | True: ear | Predicted: yawl
# 9927 | True: ear | Predicted: yawl
# 9928 | True: ear | Predicted: tile_roof
# 9929 | True: ear | Predicted: yawl
# 9930 | True: ear | Predicted: yawl
# 9931 | True: ear | Predicted: file
# 9932 | True: ear | Predicted: yawl
# 9933 | True: ear | Predicted: yawl
# 9934 | True: ear | Predicted: ashcan
# 9935 | True: ear | Predicted: yawl
# 9936 | True: ear | Predicted: yawl
# 9937 | True: ear | Predicted: yawl
# 9938 | True: ear | Predicted: yawl
# 9939 | True: ear | Predicted: yawl
# 9940 | True: ear | Predicted: yawl
# 9941 | True: ear | Predicted: yawl
# 9942 | True: ear | Predicted: yawl
# 9943 | True: ear | Predicted: yawl
# 9944 | True: ear | Predicted: yawl
# 9945 | True: ear | Predicted: yawl
# 9946 | True: ear | Predicted: yawl
# 9947 | True: ear | Predicted: yawl
# 9948 | True: ear | Predicted: yawl
# 9949 | True: ear | Predicted: yawl
# 9950 | True: ear | Predicted: yawl
# 9951 | True: ear | Predicted: yawl
# 9952 | True: ear | Predicted: yawl
# 9953 | True: ear | Predicted: yawl
# 9954 | True: ear | Predicted: yawl
# 9955 | True: ear | Predicted: yawl
# 9956 | True: ear | Predicted: yawl
# 9957 | True: ear | Predicted: yawl
# 9958 | True: ear | Predicted: yawl
# 9959 | True: ear | Predicted: yawl
# 9960 | True: ear | Predicted: yawl
# 9961 | True: ear | Predicted: yawl
# 9962 | True: ear | Predicted: yawl
# 9963 | True: ear | Predicted: yawl
# 9964 | True: ear | Predicted: yawl
# 9965 | True: ear | Predicted: yawl
# 9966 | True: ear | Predicted: yawl
# 9967 | True: ear | Predicted: yawl
# 9968 | True: ear | Predicted: ear
# 9969 | True: ear | Predicted: yawl
# 9970 | True: ear | Predicted: yawl
# 9971 | True: ear | Predicted: yawl
# 9972 | True: ear | Predicted: yawl
# 9973 | True: ear | Predicted: yawl
# 9974 | True: ear | Predicted: ashcan
# 9975 | True: ear | Predicted: yawl
# 9976 | True: ear | Predicted: yawl
# 9977 | True: ear | Predicted: yawl
# 9978 | True: ear | Predicted: yawl
# 9979 | True: ear | Predicted: yawl
# 9980 | True: ear | Predicted: yawl
# 9981 | True: ear | Predicted: yawl
# 9982 | True: ear | Predicted: school_bus
# 9983 | True: ear | Predicted: yawl
# 9984 | True: ear | Predicted: yawl
# 9985 | True: ear | Predicted: yawl
# 9986 | True: ear | Predicted: ashcan
# 9987 | True: ear | Predicted: yawl
# 9988 | True: ear | Predicted: yawl
# 9989 | True: ear | Predicted: yawl
# 9990 | True: ear | Predicted: yawl
# 9991 | True: ear | Predicted: yawl
# 9992 | True: ear | Predicted: yawl
# 9993 | True: ear | Predicted: yawl
# 9994 | True: ear | Predicted: green_mamba
# 9995 | True: ear | Predicted: yawl
# 9996 | True: ear | Predicted: yawl
# 9997 | True: ear | Predicted: yawl
# 9998 | True: ear | Predicted: yawl
# 9999 | True: ear | Predicted: yawl

# %%
np.save(f'results/true_labels.npy', true_labels)
np.save(f'results/pred_labels.npy', pred_labels)
